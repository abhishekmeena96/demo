# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
data=pd.read_excel(r"C:\Users\Lenovo\Desktop\Machine Learning\ML Live Flight Fare Resourses16963295320.xlsx")
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
data.drop("Route",axis=1,inplace=True)
data.drop("Additional_Info",axis=1,inplace=True)

# %%
data.isnull().any()
# Out:
# Airline            False
# Date_of_Journey    False
# Source             False
# Destination        False
# Dep_Time           False
# Arrival_Time       False
# Duration           False
# Total_Stops         True
# Price              False
# dtype: bool

# %%
data[data["Total_Stops"].isnull()==True]
# Out:
#         Airline Date_of_Journey Source Destination Dep_Time  Arrival_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin    09:45  09:25 07 May
#
#      Duration Total_Stops  Price
# 9039  23h 40m         NaN   7480

# %%
data.dropna(inplace=True)

# %%
data.isnull().any()
# Out:
# Airline            False
# Date_of_Journey    False
# Source             False
# Destination        False
# Dep_Time           False
# Arrival_Time       False
# Duration           False
# Total_Stops        False
# Price              False
# dtype: bool

# %%
data["Journey_Date"]=pd.to_datetime(data["Date_of_Journey"]).dt.day
data["Journey_month"]=pd.to_datetime(data["Date_of_Journey"]).dt.month

# %%
data.drop("Date_of_Journey",axis=1,inplace=True)

# %%
data["Dep_Hour"]=pd.to_datetime(data["Dep_Time"]).dt.hour
data["Dep_Min"]=pd.to_datetime(data["Dep_Time"]).dt.minute

data["Arrival_Hour"]=pd.to_datetime(data["Arrival_Time"]).dt.hour
data["Arrival_Min"]=pd.to_datetime(data["Arrival_Time"]).dt.minute

# %%
data.drop(["Dep_Time","Arrival_Time"], axis=1 ,inplace=True)

# %%
data.head()
# Out:
#        Airline    Source Destination Duration Total_Stops  Price  \
# 0       IndiGo  Banglore   New Delhi   2h 50m    non-stop   3897
# 1    Air India   Kolkata    Banglore   7h 25m     2 stops   7662
# 2  Jet Airways     Delhi      Cochin      19h     2 stops  13882
# 3       IndiGo   Kolkata    Banglore   5h 25m      1 stop   6218
# 4       IndiGo  Banglore   New Delhi   4h 45m      1 stop  13302
#
#    Journey_Date  Journey_month  Dep_Hour  Dep_Min  Arrival_Hour  Arrival_Min
# 0            24              3        22       20             1           10
# 1             1              5         5       50            13           15
# 2             9              6         9       25             4           25
# 3            12              5        18        5            23           30
# 4             1              3        16       50            21           35

# %%
data["Total_Stops"].replace(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],[0,2,1,3,4],regex=True,inplace=True)

# %%
Airline=pd.get_dummies(data["Airline"])
Source=pd.get_dummies(data["Source"])
Destination=pd.get_dummies(data["Destination"])

# %%
data
# Out:
#            Airline    Source Destination Duration  Total_Stops  Price  \
# 0           IndiGo  Banglore   New Delhi   2h 50m            0   3897
# 1        Air India   Kolkata    Banglore   7h 25m            2   7662
# 2      Jet Airways     Delhi      Cochin      19h            2  13882
# 3           IndiGo   Kolkata    Banglore   5h 25m            1   6218
# 4           IndiGo  Banglore   New Delhi   4h 45m            1  13302
# ...            ...       ...         ...      ...          ...    ...
# 10678     Air Asia   Kolkata    Banglore   2h 30m            0   4107
# 10679    Air India   Kolkata    Banglore   2h 35m            0   4145
# 10680  Jet Airways  Banglore       Delhi       3h            0   7229
# 10681      Vistara  Banglore   New Delhi   2h 40m            0  12648
# 10682    Air India     Delhi      Cochin   8h 20m            2  11753
#
#        Journey_Date  Journey_month  Dep_Hour  Dep_Min  Arrival_Hour  \
# 0                24              3        22       20             1
# 1                 1              5         5       50            13
# 2                 9              6         9       25             4
# 3                12              5        18        5            23
# 4                 1              3        16       50            21
# ...             ...            ...       ...      ...           ...
# 10678             9              4        19       55            22
# 10679            27              4        20       45            23
# 10680            27              4         8       20            11
# 10681             1              3        11       30            14
# 10682             9              5        10       55            19
#
#        Arrival_Min
# 0               10
# 1               15
# 2               25
# 3               30
# 4               35
# ...            ...
# 10678           25
# 10679           20
# 10680           20
# 10681           10
# 10682           15
#
# [10682 rows x 12 columns]

# %%
data=pd.concat([data,Airline,Source,Destination],axis=1)

# %%
data
# Out:
#            Airline    Source Destination Duration  Total_Stops  Price  \
# 0           IndiGo  Banglore   New Delhi   2h 50m            0   3897
# 1        Air India   Kolkata    Banglore   7h 25m            2   7662
# 2      Jet Airways     Delhi      Cochin      19h            2  13882
# 3           IndiGo   Kolkata    Banglore   5h 25m            1   6218
# 4           IndiGo  Banglore   New Delhi   4h 45m            1  13302
# ...            ...       ...         ...      ...          ...    ...
# 10678     Air Asia   Kolkata    Banglore   2h 30m            0   4107
# 10679    Air India   Kolkata    Banglore   2h 35m            0   4145
# 10680  Jet Airways  Banglore       Delhi       3h            0   7229
# 10681      Vistara  Banglore   New Delhi   2h 40m            0  12648
# 10682    Air India     Delhi      Cochin   8h 20m            2  11753
#
#        Journey_Date  Journey_month  Dep_Hour  Dep_Min  ...  Chennai  Delhi  \
# 0                24              3        22       20  ...    False  False
# 1                 1              5         5       50  ...    False  False
# 2                 9              6         9       25  ...    False   True
# 3                12              5        18        5  ...    False  False
# 4                 1              3        16       50  ...    False  False
# ...             ...            ...       ...      ...  ...      ...    ...
# 10678             9              4        19       55  ...    False  False
# 10679            27              4        20       45  ...    False  False
# 10680            27              4         8       20  ...    False  False
# 10681             1              3        11       30  ...    False  False
# 10682             9              5        10       55  ...    False   True
#
#        Kolkata  Mumbai  Banglore  Cochin  Delhi  Hyderabad  Kolkata  New Delhi
# 0        False   False     False   False  False      False    False       True
# 1         True   False      True   False  False      False    False      False
# 2        False   False     False    True  False      False    False      False
# 3         True   False      True   False  False      False    False      False
# 4        False   False     False   False  False      False    False       True
# ...        ...     ...       ...     ...    ...        ...      ...        ...
# 10678     True   False      True   False  False      False    False      False
# 10679     True   False      True   False  False      False    False      False
# 10680    False   False     False   False   True      False    False      False
# 10681    False   False     False   False  False      False    False       True
# 10682    False   False     False    True  False      False    False      False
#
# [10682 rows x 35 columns]

# %%
data.drop(["Airline","Source","Destination"],axis=1,inplace=True)

# %%
pd.set_option("display.max_columns",None)

# %%
data["Duration_hour"]=data["Duration"].str.split("h").str[0]

# %%
data["Duration_min"]=data["Duration"].str.split("h").str[1].str.split("m").str[0].str.strip()

# %%
data["Duration_hour"].unique()
# Out:
# array(['2', '7', '19', '5', '4', '15', '21', '25', '13', '12', '26', '22',
#        '23', '20', '10', '6', '11', '8', '16', '3', '27', '1', '14', '9',
#        '18', '17', '24', '30', '28', '29', '37', '34', '38', '35', '36',
#        '47', '33', '32', '31', '42', '39', '5m', '41', '40'], dtype=object)

# %%
data["Duration_hour"].replace("[m]","",regex=True,inplace=True)

# %%
data["Duration_hour"].unique()
# Out:
# array(['2', '7', '19', '5', '4', '15', '21', '25', '13', '12', '26', '22',
#        '23', '20', '10', '6', '11', '8', '16', '3', '27', '1', '14', '9',
#        '18', '17', '24', '30', '28', '29', '37', '34', '38', '35', '36',
#        '47', '33', '32', '31', '42', '39', '41', '40'], dtype=object)

# %%
data["Duration_min"].replace("",0,inplace=True)

# %%
data["Duration_min"].replace(np.nan,0,inplace=True)

# %%
data.drop("Duration",axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10682 entries, 0 to 10682
# Data columns (total 33 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Total_Stops                        10682 non-null  int64
#  1   Price                              10682 non-null  int64
#  2   Journey_Date                       10682 non-null  int32
#  3   Journey_month                      10682 non-null  int32
#  4   Dep_Hour                           10682 non-null  int32
#  5   Dep_Min                            10682 non-null  int32
#  6   Arrival_Hour                       10682 non-null  int32
#  7   Arrival_Min                        10682 non-null  int32
#  8   Air Asia                           10682 non-null  bool
#  9   Air India                          10682 non-null  bool
#  10  GoAir                              10682 non-null  bool
#  11  IndiGo                             10682 non-null  bool
#  12  Jet Airways                        10682 non-null  bool
#  13  Jet Airways Business               10682 non-null  bool
#  14  Multiple carriers                  10682 non-null  bool
#  15  Multiple carriers Premium economy  10682 non-null  bool
#  16  SpiceJet                           10682 non-null  bool
#  17  Trujet                             10682 non-null  bool
#  18  Vistara                            10682 non-null  bool
#  19  Vistara Premium economy            10682 non-null  bool
#  20  Banglore                           10682 non-null  bool
#  21  Chennai                            10682 non-null  bool
#  22  Delhi                              10682 non-null  bool
#  23  Kolkata                            10682 non-null  bool
#  24  Mumbai                             10682 non-null  bool
#  25  Banglore                           10682 non-null  bool
#  26  Cochin                             10682 non-null  bool
#  27  Delhi                              10682 non-null  bool
#  28  Hyderabad                          10682 non-null  bool
#  29  Kolkata                            10682 non-null  bool
#  30  New Delhi                          10682 non-null  bool
#  31  Duration_hour                      10682 non-null  object
#  32  Duration_min                       10682 non-null  object
# dtypes: bool(23), int32(6), int64(2), object(2)
# memory usage: 907.6+ KB

# %%
data[["Duration_min","Duration_hour"]]=data[["Duration_min","Duration_hour"]].astype(int)

# %%
data.columns
# Out:
# Index(['Total_Stops', 'Price', 'Journey_Date', 'Journey_month', 'Dep_Hour',
#        'Dep_Min', 'Arrival_Hour', 'Arrival_Min', 'Air Asia', 'Air India',
#        'GoAir', 'IndiGo', 'Jet Airways', 'Jet Airways Business',
#        'Multiple carriers', 'Multiple carriers Premium economy', 'SpiceJet',
#        'Trujet', 'Vistara', 'Vistara Premium economy', 'Banglore', 'Chennai',
#        'Delhi', 'Kolkata', 'Mumbai', 'Banglore', 'Cochin', 'Delhi',
#        'Hyderabad', 'Kolkata', 'New Delhi', 'Duration_hour', 'Duration_min'],
#       dtype='object')

# %%
data=data[['Total_Stops', 'Journey_Date', 'Journey_month', 'Dep_Hour',
       'Dep_Min', 'Arrival_Hour', 'Arrival_Min', 'Air Asia', 'Air India',
       'GoAir', 'IndiGo', 'Jet Airways', 'Jet Airways Business',
       'Multiple carriers', 'Multiple carriers Premium economy', 'SpiceJet',
       'Trujet', 'Vistara', 'Vistara Premium economy', 'Banglore', 'Chennai',
       'Delhi', 'Kolkata', 'Mumbai', 'Banglore', 'Cochin', 'Delhi',
       'Hyderabad', 'Kolkata', 'New Delhi', 'Duration_hour', 'Duration_min','Price']]

# %%
data
# Out:
#        Total_Stops  Journey_Date  Journey_month  Dep_Hour  Dep_Min  \
# 0                0            24              3        22       20
# 1                2             1              5         5       50
# 2                2             9              6         9       25
# 3                1            12              5        18        5
# 4                1             1              3        16       50
# ...            ...           ...            ...       ...      ...
# 10678            0             9              4        19       55
# 10679            0            27              4        20       45
# 10680            0            27              4         8       20
# 10681            0             1              3        11       30
# 10682            2             9              5        10       55
#
#        Arrival_Hour  Arrival_Min  Air Asia  Air India  GoAir  IndiGo  \
# 0                 1           10     False      False  False    True
# 1                13           15     False       True  False   False
# 2                 4           25     False      False  False   False
# 3                23           30     False      False  False    True
# 4                21           35     False      False  False    True
# ...             ...          ...       ...        ...    ...     ...
# 10678            22           25      True      False  False   False
# 10679            23           20     False       True  False   False
# 10680            11           20     False      False  False   False
# 10681            14           10     False      False  False   False
# 10682            19           15     False       True  False   False
#
#        Jet Airways  Jet Airways Business  Multiple carriers  \
# 0            False                 False              False
# 1            False                 False              False
# 2             True                 False              False
# 3            False                 False              False
# 4            False                 False              False
# ...            ...                   ...                ...
# 10678        False                 False              False
# 10679        False                 False              False
# 10680         True                 False              False
# 10681        False                 False              False
# 10682        False                 False              False
#
#        Multiple carriers Premium economy  SpiceJet  Trujet  Vistara  \
# 0                                  False     False   False    False
# 1                                  False     False   False    False
# 2                                  False     False   False    False
# 3                                  False     False   False    False
# 4                                  False     False   False    False
# ...                                  ...       ...     ...      ...
# 10678                              False     False   False    False
# 10679                              False     False   False    False
# 10680                              False     False   False    False
# 10681                              False     False   False     True
# 10682                              False     False   False    False
#
#        Vistara Premium economy  Banglore  Banglore  Chennai  Delhi  Delhi  \
# 0                        False      True     False    False  False  False
# 1                        False     False      True    False  False  False
# 2                        False     False     False    False   True  False
# 3                        False     False      True    False  False  False
# 4                        False      True     False    False  False  False
# ...                        ...       ...       ...      ...    ...    ...
# 10678                    False     False      True    False  False  False
# 10679                    False     False      True    False  False  False
# 10680                    False      True     False    False  False   True
# 10681                    False      True     False    False  False  False
# 10682                    False     False     False    False   True  False
#
#        Kolkata  Kolkata  Mumbai  Banglore  Banglore  Cochin  Delhi  Delhi  \
# 0        False    False   False      True     False   False  False  False
# 1         True    False   False     False      True   False  False  False
# 2        False    False   False     False     False    True   True  False
# 3         True    False   False     False      True   False  False  False
# 4        False    False   False      True     False   False  False  False
# ...        ...      ...     ...       ...       ...     ...    ...    ...
# 10678     True    False   False     False      True   False  False  False
# 10679     True    False   False     False      True   False  False  False
# 10680    False    False   False      True     False   False  False   True
# 10681    False    False   False      True     False   False  False  False
# 10682    False    False   False     False     False    True   True  False
#
#        Hyderabad  Kolkata  Kolkata  New Delhi  Duration_hour  Duration_min  \
# 0          False    False    False       True              2            50
# 1          False     True    False      False              7            25
# 2          False    False    False      False             19             0
# 3          False     True    False      False              5            25
# 4          False    False    False       True              4            45
# ...          ...      ...      ...        ...            ...           ...
# 10678      False     True    False      False              2            30
# 10679      False     True    False      False              2            35
# 10680      False    False    False      False              3             0
# 10681      False    False    False       True              2            40
# 10682      False    False    False      False              8            20
#
#        Price
# 0       3897
# 1       7662
# 2      13882
# 3       6218
# 4      13302
# ...      ...
# 10678   4107
# 10679   4145
# 10680   7229
# 10681  12648
# 10682  11753
#
# [10682 rows x 39 columns]

# %%
x=data.drop("Price",axis=1)
y=data["Price"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((7477, 38), (3205, 38), (7477,), (3205,))

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("Training Accuracy",model.score(x_train,y_train))
print("Testinig Accuracy",model.score(x_test,y_test))
# Out:
# Training Accuracy 0.6216960700942382
# Testinig Accuracy 0.6263919372557317

# %%
from sklearn.linear_model import Lasso
model1=Lasso(alpha=10)
model1.fit(x_train,y_train)
# Out:
# Lasso(alpha=10)

# %%
print("Training Accuracy",model1.score(x_train,y_train))
print("Testinig Accuracy",model1.score(x_test,y_test))
# Out:
# Training Accuracy 0.6132720629190056
# Testinig Accuracy 0.6213205878457586

# %%
# feature selection--jab number of columns jiydad ho or ccomplexity bad gai ho(numver of columns),---- feature selection bata hai ki number of columns important hai

# %%
data.corr()
# Out:
#                                    Total_Stops  Journey_Date  Journey_month  \
# Total_Stops                           1.000000     -0.009451       0.054383
# Journey_Date                         -0.009451      1.000000      -0.038359
# Journey_month                         0.054383     -0.038359       1.000000
# Dep_Hour                             -0.061476      0.002170       0.039127
# Dep_Min                              -0.002618     -0.008170      -0.059267
# Arrival_Hour                          0.038140     -0.003245      -0.003927
# Arrival_Min                          -0.106940     -0.017510      -0.100626
# Air Asia                             -0.094423      0.008926       0.005652
# Air India                             0.271094     -0.032490      -0.045981
# GoAir                                -0.060110     -0.003122      -0.004494
# IndiGo                               -0.302991      0.007281      -0.048504
# Jet Airways                           0.215063     -0.017304       0.059735
# Jet Airways Business                  0.017876     -0.031713      -0.034787
# Multiple carriers                     0.118399      0.042163       0.053685
# Multiple carriers Premium economy     0.009089      0.030839      -0.051222
# SpiceJet                             -0.274351      0.022154      -0.011977
# Trujet                                0.002519     -0.008569      -0.014199
# Vistara                              -0.120447     -0.013169      -0.017252
# Vistara Premium economy              -0.020459     -0.020115      -0.019797
# Banglore                             -0.368324     -0.050438      -0.244418
# Banglore                              0.032761     -0.060558       0.087177
# Chennai                              -0.234758      0.006611       0.005650
# Delhi                                 0.490170      0.100088       0.139222
# Delhi                                -0.447390      0.002632       0.090490
# Kolkata                               0.032761     -0.060558       0.087177
# Kolkata                              -0.234758      0.006611       0.005650
# Mumbai                               -0.260752     -0.014030      -0.039352
# Banglore                             -0.368324     -0.050438      -0.244418
# Banglore                              0.032761     -0.060558       0.087177
# Cochin                                0.490170      0.100088       0.139222
# Delhi                                 0.490170      0.100088       0.139222
# Delhi                                -0.447390      0.002632       0.090490
# Hyderabad                            -0.260752     -0.014030      -0.039352
# Kolkata                               0.032761     -0.060558       0.087177
# Kolkata                              -0.234758      0.006611       0.005650
# New Delhi                            -0.015302     -0.075254      -0.453685
# Duration_hour                         0.740049     -0.022109       0.016061
# Duration_min                         -0.136749     -0.008915      -0.040854
# Price                                 0.603897     -0.153774      -0.103643
#
#                                    Dep_Hour   Dep_Min  Arrival_Hour  \
# Total_Stops                       -0.061476 -0.002618      0.038140
# Journey_Date                       0.002170 -0.008170     -0.003245
# Journey_month                      0.039127 -0.059267     -0.003927
# Dep_Hour                           1.000000 -0.024745      0.005180
# Dep_Min                           -0.024745  1.000000      0.043122
# Delhi                                 0.095250  0.056552  -0.068370  0.099863
# Kolkata                               0.118573  0.079726   0.023606 -0.042921
# Kolkata                              -0.030493 -0.033742  -0.051068 -0.026156
# Mumbai                                0.081196 -0.046355   0.022268 -0.035933
# Banglore                              0.090993  0.031828  -0.017601  0.092099
# Banglore                              0.118573  0.079726   0.023606 -0.042921
# Cochin                               -0.209882 -0.061711   0.001257 -0.009049
# Delhi                                -0.209882 -0.061711   0.001257 -0.009049
# Delhi                                 0.095250  0.056552  -0.068370  0.099863
# Hyderabad                             0.081196 -0.046355   0.022268 -0.035933
# Kolkata                               0.118573  0.079726   0.023606 -0.042921
# Kolkata                              -0.030493 -0.033742  -0.051068 -0.026156
# New Delhi                             0.021271 -0.019163   0.053072  0.017573
# Duration_hour                        -0.074352 -0.104331   0.261845 -0.094056
# Duration_min                          0.151571  0.085814  -0.033488  0.067216
# Price                                -0.086155 -0.133050   0.050432 -0.095151
#
#                                      IndiGo  Jet Airways  \
# Total_Stops                       -0.302991     0.215063
# Journey_Date                       0.007281    -0.017304
# Journey_month                     -0.048504     0.059735
# Dep_Hour                          -0.023395     0.113942
# Dep_Min                           -0.014714     0.024455
# Arrival_Hour                      -0.071491    -0.027377
# Arrival_Min                        0.035124    -0.057698
# Air Asia                          -0.085579    -0.131680
# Air India                         -0.215977    -0.332324
# GoAir                             -0.066339    -0.102076
# IndiGo                             1.000000    -0.366085
# Jet Airways                       -0.366085     1.000000
# Jet Airways Business              -0.011563    -0.017793
# Multiple carriers                 -0.173196    -0.266497
# Multiple carriers Premium economy -0.017026    -0.026199
# SpiceJet                          -0.140464    -0.216132
# Trujet                            -0.004720    -0.007262
# Vistara                           -0.105686    -0.162619
# Vistara Premium economy           -0.008175    -0.012580
# Banglore                           0.059224    -0.001754
# Banglore                          -0.057229     0.097428
# Chennai                            0.141911    -0.144341
# Delhi                             -0.080168    -0.019108
# Delhi                              0.090354    -0.051787
# Kolkata                           -0.057229     0.097428
# Kolkata                            0.141911    -0.144341
# Mumbai                             0.059686    -0.025382
# Banglore                           0.059224    -0.001754
# Banglore                          -0.057229     0.097428
# Cochin                            -0.080168    -0.019108
# Delhi                             -0.080168    -0.019108
# Delhi                              0.090354    -0.051787
# Hyderabad                          0.059686    -0.025382
# Kolkata                           -0.057229     0.097428
# Kolkata                            0.141911    -0.144341
# New Delhi                         -0.018626     0.056782
# Duration_hour                     -0.346274     0.307170
# Duration_min                       0.119825    -0.084028
# Price                             -0.361070     0.416124
#
#                                    Jet Airways Business  Multiple carriers  \
# Total_Stops                                    0.017876           0.118399
# Journey_Date                                  -0.031713           0.042163
# Journey_month                                 -0.034787           0.053685
# Dep_Hour                                      -0.007524          -0.149992
# Dep_Min                                        0.009168          -0.109370
# Arrival_Hour                                  -0.014456           0.067930
# Arrival_Min                                    0.005232          -0.167455
# Air Asia                                      -0.004159          -0.062298
# Air India                                     -0.010497          -0.157223
# GoAir                                         -0.003224          -0.048292
# IndiGo                                        -0.011563          -0.173196
# Jet Airways                                   -0.017793          -0.266497
# Jet Airways Business                           1.000000          -0.008418
# Multiple carriers                             -0.008418           1.000000
# Multiple carriers Premium economy             -0.000828          -0.012395
# SpiceJet                                      -0.006827          -0.102253
# Trujet                                        -0.000229          -0.003436
# Vistara                                       -0.005137          -0.076936
# Vistara Premium economy                       -0.000397          -0.005951
# Banglore                                       0.027038          -0.180681
# Banglore                                      -0.014373          -0.215272
# Chennai                                       -0.004559          -0.068288
# Delhi                                         -0.004379           0.413317
# Delhi                                         -0.008689          -0.130141
# Kolkata                                       -0.014373          -0.215272
# Kolkata                                       -0.004559          -0.068288
# Mumbai                                        -0.006263          -0.093814
# Banglore                                       0.027038          -0.180681
# Banglore                                      -0.014373          -0.215272
# Cochin                                        -0.004379           0.413317
# Delhi                                         -0.004379           0.413317
# Delhi                                         -0.008689          -0.130141
# Hyderabad                                     -0.006263          -0.093814
# Kolkata                                       -0.014373          -0.215272
# Kolkata                                       -0.004559          -0.068288
# New Delhi                                      0.048675          -0.109782
# Duration_hour                                 -0.011849          -0.008090
# Duration_min                                  -0.002322          -0.118752
# Price                                          0.253303           0.139793
#
#                                    Multiple carriers Premium economy  \
# Total_Stops                                                 0.009089
# Journey_Date                                                0.030839
# Journey_month                                              -0.051222
# Dep_Hour                                                   -0.028672
# Dep_Min                                                    -0.004624
# Arrival_Hour                                                0.013491
# Arrival_Min                                                -0.001786
# Air Asia                                                   -0.006124
# Air India                                                  -0.015456
# GoAir                                                      -0.004747
# IndiGo                                                     -0.017026
# Jet Airways                                                -0.026199
# Jet Airways Business                                       -0.000828
# Multiple carriers                                          -0.012395
# Multiple carriers Premium economy                           1.000000
# SpiceJet                                                   -0.010052
# Trujet                                                     -0.000338
# Vistara                                                    -0.007563
# Vistara Premium economy                                    -0.000585
# Banglore                                                   -0.017762
# Banglore                                                   -0.021163
# Chennai                                                    -0.006713
# Delhi                                                       0.040632
# Delhi                                                      -0.012794
# Kolkata                                                    -0.021163
# Kolkata                                                    -0.006713
# Mumbai                                                     -0.009223
# Banglore                                                   -0.017762
# Banglore                                                   -0.021163
# Cochin                                                      0.040632
# Delhi                                                       0.040632
# Delhi                                                      -0.012794
# Hyderabad                                                  -0.009223
# Kolkata                                                    -0.021163
# Kolkata                                                    -0.006713
# New Delhi                                                  -0.010792
# Duration_hour                                              -0.002273
# Duration_min                                               -0.006852
# Price                                                       0.017650
#
#                                    SpiceJet    Trujet   Vistara  \
# Total_Stops                       -0.274351  0.002519 -0.120447
# Journey_Date                       0.022154 -0.008569 -0.013169
# Journey_month                     -0.011977 -0.014199 -0.017252
# Dep_Hour                          -0.010451  0.000857  0.023906
# Dep_Min                            0.092634 -0.010007 -0.077903
# Arrival_Hour                      -0.090058  0.003739  0.068834
# Arrival_Min                        0.012543 -0.002750  0.069422
# Air Asia                          -0.050525 -0.001698 -0.038015
# Air India                         -0.127510 -0.004284 -0.095939
# GoAir                             -0.039166 -0.001316 -0.029469
# IndiGo                            -0.140464 -0.004720 -0.105686
# Jet Airways                       -0.216132 -0.007262 -0.162619
# Jet Airways Business              -0.006827 -0.000229 -0.005137
# Multiple carriers                 -0.102253 -0.003436 -0.076936
# Multiple carriers Premium economy -0.010052 -0.000338 -0.007563
# SpiceJet                           1.000000 -0.002786 -0.062396
# Trujet                            -0.002786  1.000000 -0.002097
# Vistara                           -0.062396 -0.002097  1.000000
# Vistara Premium economy           -0.004827 -0.000162 -0.003632
# Banglore                           0.011113 -0.004924  0.096785
# Banglore                           0.063645 -0.005866  0.055364
# Chennai                            0.187590 -0.001861  0.063208
# Delhi                             -0.185431 -0.008313 -0.144961
# Delhi                              0.043723 -0.003546  0.103983
# Kolkata                            0.063645 -0.005866  0.055364
# Kolkata                            0.187590 -0.001861  0.063208
# Mumbai                             0.097824  0.036623 -0.015119
# Banglore                           0.011113 -0.004924  0.096785
# Banglore                           0.063645 -0.005866  0.055364
# Cochin                            -0.185431 -0.008313 -0.144961
# Delhi                             -0.185431 -0.008313 -0.144961
# Delhi                              0.043723 -0.003546  0.103983
# Hyderabad                          0.097824  0.036623 -0.015119
# Kolkata                            0.063645 -0.005866  0.055364
# Kolkata                            0.187590 -0.001861  0.063208
# New Delhi                         -0.034144 -0.002992  0.019568
# Duration_hour                     -0.263873 -0.008253 -0.020371
# Duration_min                       0.041325 -0.007609  0.041956
# Price                             -0.296565 -0.010381 -0.060654
#
#                                    Vistara Premium economy  Banglore  \
# Total_Stops                                      -0.020459 -0.368324
# Journey_Date                                     -0.020115 -0.050438
# Journey_month                                    -0.019797 -0.244418
# Dep_Hour                                         -0.003375 -0.007887
# Dep_Min                                          -0.011380  0.077354
# Arrival_Hour                                      0.000776 -0.024419
# Arrival_Min                                       0.000314  0.090993
# Air Asia                                         -0.002941  0.031828
# Air India                                        -0.007421 -0.017601
# GoAir                                            -0.002280  0.092099
# IndiGo                                           -0.008175  0.059224
# Jet Airways                                      -0.012580 -0.001754
# Jet Airways Business                             -0.000397  0.027038
# Multiple carriers                                -0.005951 -0.180681
# Multiple carriers Premium economy                -0.000585 -0.017762
# SpiceJet                                         -0.004827  0.011113
# Trujet                                           -0.000162 -0.004924
# Vistara                                          -0.003632  0.096785
# Vistara Premium economy                           1.000000  0.019116
# Banglore                                          0.019116  1.000000
# Banglore                                         -0.010162 -0.308498
# Chennai                                           0.026901 -0.097862
# Delhi                                            -0.014399 -0.437149
# Delhi                                             0.011148  0.720278
# Kolkata                                          -0.010162 -0.308498
# Kolkata                                           0.026901 -0.097862
# Mumbai                                           -0.004428 -0.134441
# Banglore                                          0.019116  1.000000
# Banglore                                         -0.010162 -0.308498
# Cochin                                           -0.014399 -0.437149
# Delhi                                            -0.014399 -0.437149
# Delhi                                             0.011148  0.720278
# Hyderabad                                        -0.004428 -0.134441
# Kolkata                                          -0.010162 -0.308498
# Kolkata                                           0.026901 -0.097862
# New Delhi                                         0.014616  0.607598
# Duration_hour                                    -0.016270 -0.273956
# Duration_min                                      0.004953  0.230199
# Price                                            -0.000454 -0.118044
#
#                                    Banglore   Chennai     Delhi     Delhi  \
# Total_Stops                        0.032761 -0.234758  0.490170 -0.447390
# Journey_Date                      -0.060558  0.006611  0.100088  0.002632
# Journey_month                      0.087177  0.005650  0.139222  0.090490
# Dep_Hour                           0.155471 -0.014846 -0.118780  0.009469
# Duration_min                       -0.018865  0.013777 -0.098814   0.079871
# Price                              -0.230755  0.009358 -0.179223   0.189777
#
#                                    Duration_hour  Duration_min     Price
# Total_Stops                             0.740049     -0.136749  0.603897
# Journey_Date                           -0.022109     -0.008915 -0.153774
# Journey_month                           0.016061     -0.040854 -0.103643
# Dep_Hour                                0.002903     -0.023723  0.006799
# Dep_Min                                -0.022030      0.092443 -0.024458
# Arrival_Hour                            0.055300     -0.118315  0.024244
# Arrival_Min                            -0.074352      0.151571 -0.086155
# Air Asia                               -0.104331      0.085814 -0.133050
# Air India                               0.261845     -0.033488  0.050432
# GoAir                                  -0.094056      0.067216 -0.095151
# IndiGo                                 -0.346274      0.119825 -0.361070
# Jet Airways                             0.307170     -0.084028  0.416124
# Jet Airways Business                   -0.011849     -0.002322  0.253303
# Multiple carriers                      -0.008090     -0.118752  0.139793
# Multiple carriers Premium economy      -0.002273     -0.006852  0.017650
# SpiceJet                               -0.263873      0.041325 -0.296565
# Trujet                                 -0.008253     -0.007609 -0.010381
# Vistara                                -0.020371      0.041956 -0.060654
# Vistara Premium economy                -0.016270      0.004953 -0.000454
# Banglore                               -0.273956      0.230199 -0.118044
# Banglore                                0.123497      0.013777  0.009358
# Chennai                                -0.186688     -0.098814 -0.179223
# Delhi                                   0.299786     -0.154096  0.270676
# Delhi                                  -0.346230      0.218208 -0.313417
# Kolkata                                 0.123497      0.013777  0.009358
# Kolkata                                -0.186688     -0.098814 -0.179223
# Mumbai                                 -0.233130     -0.018865 -0.230755
# Banglore                               -0.273956      0.230199 -0.118044
# Banglore                                0.123497      0.013777  0.009358
# Cochin                                  0.299786     -0.154096  0.270676
# Delhi                                   0.299786     -0.154096  0.270676
# Delhi                                  -0.346230      0.218208 -0.313417
# Hyderabad                              -0.233130     -0.018865 -0.230755
# Kolkata                                 0.123497      0.013777  0.009358
# Kolkata                                -0.186688     -0.098814 -0.179223
# New Delhi                               0.004035      0.079871  0.189777
# Duration_hour                           1.000000     -0.126528  0.508902
# Duration_min                           -0.126528      1.000000 -0.124899
# Price                                   0.508902     -0.124899  1.000000

# %%
from sklearn.ensemble import ExtraTreesRegressor
model3=ExtraTreesRegressor()
model3.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
a=pd.Series(model3.feature_importances_,index=x.columns)
a
# Out:
# Total_Stops                          0.233247
# Journey_Date                         0.145464
# Journey_month                        0.052933
# Dep_Hour                             0.023866
# Dep_Min                              0.020429
# Arrival_Hour                         0.028305
# Arrival_Min                          0.018967
# Air Asia                             0.001954
# Air India                            0.008700
# GoAir                                0.001363
# IndiGo                               0.017923
# Jet Airways                          0.140394
# Jet Airways Business                 0.067196
# Multiple carriers                    0.019482
# Multiple carriers Premium economy    0.000814
# SpiceJet                             0.002833
# Trujet                               0.000127
# Vistara                              0.004801
# Vistara Premium economy              0.000084
# Banglore                             0.004574
# Banglore                             0.001014
# Chennai                              0.000296
# Delhi                                0.008081
# Delhi                                0.010275
# Kolkata                              0.001047
# Kolkata                              0.000280
# Mumbai                               0.008203
# Banglore                             0.005639
# Banglore                             0.000917
# Cochin                               0.003528
# Delhi                                0.008058
# Delhi                                0.006353
# Hyderabad                            0.006237
# Kolkata                              0.001262
# Kolkata                              0.000371
# New Delhi                            0.015359
# Duration_hour                        0.111917
# Duration_min                         0.017706
# dtype: float64

# %%
a.nlargest(20).plot(kind="barh")
# Out:
# <Axes: >

# %%
a.nlargest(20)
# Out:
# Total_Stops             0.233247
# Journey_Date            0.145464
# Jet Airways             0.140394
# Duration_hour           0.111917
# Jet Airways Business    0.067196
# Journey_month           0.052933
# Arrival_Hour            0.028305
# Dep_Hour                0.023866
# Dep_Min                 0.020429
# Multiple carriers       0.019482
# Arrival_Min             0.018967
# IndiGo                  0.017923
# Duration_min            0.017706
# New Delhi               0.015359
# Delhi                   0.010275
# Air India               0.008700
# Mumbai                  0.008203
# Delhi                   0.008081
# Delhi                   0.008058
# Delhi                   0.006353
# dtype: float64

# %%
data.shape
# Out:
# (10682, 39)

# %%
# apply all Regression algorithm in ML

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor # accurate regression model banate hain jo kai choti-choti models ko combine karke badi accuracy achieve karta hai.accuracy(precision_score ,f1score) ko balance karta hai or best accuracy find karta hai  
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

# %%
model=[DecisionTreeRegressor,RandomForestRegressor,AdaBoostRegressor,KNeighborsRegressor,SVR]

for i in model:
    reg=i()
    reg=reg.fit(x_train,y_train)
    print(i,"accuracy:",reg.score(x_test,y_test))
# Out:
# <class 'sklearn.tree._classes.DecisionTreeRegressor'> accuracy: 0.7000207404592989
# <class 'sklearn.ensemble._forest.RandomForestRegressor'> accuracy: 0.8011087487637694
# <class 'sklearn.ensemble._weight_boosting.AdaBoostRegressor'> accuracy: 0.32994490983591285
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'> accuracy: 0.5745822827320851
# <class 'sklearn.svm._classes.SVR'> accuracy: 0.004675687532239681

# %% [markdown]
# # apply Kflod and Cross validation

# %%
# change random state 
# kflod mathod -- kisme random state ki accuracy achi milti hai vo btta hai

# %%
from sklearn.model_selection import KFold,cross_val_score

# %%
models=[]
models.append(("KNN",KNeighborsRegressor()))
models.append(("DecisionTree",DecisionTreeRegressor()))
models.append(("RF",RandomForestRegressor()))
models.append(("AdaBoost",AdaBoostRegressor()))
models.append(("SVm",SVR()))

# %%
results=[]
names=[]
for name,model in models:
    a=KFold(5)
    cv_result=cross_val_score(model,x_train,y_train,cv=a)
    names.append(name)
    results.append(cv_result)

# %%
for i in range(len(names)):
    print(names[i],results[i].mean())
# Out:
# KNN 0.535879323535361
# DecisionTree 0.6836371908379049
# RF 0.8017117807524897
# AdaBoost 0.3927930527391202
# SVm -0.0056493059101819345

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
reg_rf=RandomForestRegressor()
reg_rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=reg_rf.predict(x_test)

# %%
reg_rf.score(x_train,y_train)
# Out:
# 0.9556893266135291

# %%
reg_rf.score(x_test,y_test)
# Out:
# 0.8036064738040537

# %%
#hyperparameter

# %%
model_final=RandomForestRegressor(n_estimators= 700,
 min_samples_split= 15,
 min_samples_leaf= 1,
 max_features= 'auto',
 max_depth= 20)

# %%
model_final.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=20, max_features='auto', min_samples_split=15,
#                       n_estimators=700)

# %%
model_final.score(x_train,y_train)
# Out:
# 0.8944872620066232

# %%
model_final.score(x_test,y_test)
# Out:
# 0.8155769112858804
